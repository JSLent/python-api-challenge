# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import holoviews as hv
from holoviews import opts

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a9d26a09-15c7-4c9b-be4d-86c85082e814" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        0  plettenberg bay -34.0527   23.3716    286.07        71
# 1        1         keflavik  64.0049  -22.5624    271.39        74
# 2        2           tutoia  -2.7619  -42.2744    298.91        91
# 3        3       whitehorse  60.7161 -135.0538    275.94        48
# 4        4          ushuaia -54.8000  -68.3000    278.96        81
#
#    Cloudiness  Wind Speed Country        Date
# 0          86        1.54      ZA  1712979547
# 1          40        6.17      IS  1712979548
# 2         100        3.85      BR  1712979548
# 3          75        4.63      CA  1712979548
# 4           0        3.09      AR  1712979548

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_df["Humidity"] = city_data_df["Humidity"].astype(float)

#adjust scaling of points
city_data_df["size"] = city_data_df["Humidity"] * 10

# create map plot
map_plot = city_data_df.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", hover_cols=["City","Humidity"], size= "Humidity", 
                            c="City", frame_width = 700, frame_height= 500, fill_alpha=0.5)

# customize map#line_color= "white,#line_width=0.5, 
#map_plot.opts(opts.Points(marker="circle",size=5, tools= ["hover"], 
                          #active_tools=["pan", "wheel_zoom"]))

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
#convert kelvin to fahrenheit
city_data_df["Max Temp"] = (city_data_df["Max Temp"] - 273.15) * 9/5 + 32

# Narrow down cities that fit criteria and drop any results with null values
ideal_temp = (city_data_df["Max Temp"] > 70) & (city_data_df["Max Temp"] < 90)
ideal_wind_speed = city_data_df["Wind Speed"] < 10
ideal_cloudiness = city_data_df["Cloudiness"] == 0

#combine all conditions
ideal_weather_condition = (ideal_temp & ideal_wind_speed & ideal_cloudiness)

#filter the DF
ideal_cities = city_data_df[ideal_weather_condition]
                                                
# Drop any rows with null values
ideal_cities = ideal_cities.dropna()

# Display sample data
ideal_cities.sample(5)
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 324      324  colonel hill  22.7667  -74.2167    78.512      75.0           0
# 239      239        medina  24.4686   39.6142    73.832      27.0           0
# 488      488   changnyeong  35.5415  128.4951    80.006      28.0           0
# 249      249       buckeye  33.3703 -112.5838    81.896      15.0           0
# 524      524      tuncurry -32.1667  152.5000    78.350      67.0           0
#
#      Wind Speed Country        Date   size
# 324        4.64      BS  1712979644  750.0
# 239        6.17      SA  1712979365  270.0
# 488        2.06      KR  1712979697  280.0
# 249        6.64      US  1712979412  150.0
# 524        0.89      AU  1712979709  670.0

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 0  plettenberg bay      ZA -34.0527   23.3716      71.0
# 1         keflavik      IS  64.0049  -22.5624      74.0
# 2           tutoia      BR  -2.7619  -42.2744      91.0
# 3       whitehorse      CA  60.7161 -135.0538      48.0
# 4          ushuaia      AR -54.8000  -68.3000      81.0

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey": geoapify_key, 
    "radius": radius, 
    "limit": 1,
    "categories": "accommodation.hotel", "format": "json"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat, lng = row["Lat"], row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"


    # Make and API request using the params dictionaty
    #name_address = 
    response = requests.get(base_url, params=params)

    #print request url and API response
    #print(f"Request URL: {response.url}")
    #print(f"API Response: {response.json()}")
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# plettenberg bay - nearest hotel: Milkwood Manor
# keflavik - nearest hotel: Núpan Deluxe
# tutoia - nearest hotel: Pousada San Vicente
# whitehorse - nearest hotel: Town & Mountain Hotel
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# yellowknife - nearest hotel: No hotel found
# blackmans bay - nearest hotel: Villa Howden
# wenchang - nearest hotel: No hotel found
# bethel - nearest hotel: Hampton Inn Danbury
# olonkinbyen - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# bilibino - nearest hotel: No hotel found
# monrovia - nearest hotel: Bella Casa Hotel
# edinburgh of the seven seas - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# santa terezinha - nearest hotel: Pousada Santa Terezinha
# invercargill - nearest hotel: The Grand
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# gamba - nearest hotel: No hotel found
# zapala - nearest hotel: Apart Solar de Piedra
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
#fiter out rows where no hotel found
hotel_df_filtered = hotel_df[hotel_df["Hotel Name"] != "No hotel found"].head(50) 

# Configure the map plot
map_plot = hotel_df_filtered.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", hover_cols=["City","Hotel Name", "Country"], size= "Humidity", 
                            c="City", frame_width = 700, frame_height= 500, fill_alpha=0.5) 

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
